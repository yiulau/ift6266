# %%
import timeit

# %%
from fuel.streams import ServerDataStream
data_stream = ServerDataStream(('image_features','target'),False)
#iterator = data_stream.get_epoch_iterator()
#start_time = timeit.default_timer()
#one_batch = next(iterator)
#total_time = timeit.default_timer() - start_time

# %%
total_time
# Out:
# 0.0037763119908049703

# %%
from fuel.streams import ServerDataStream
valid_stream = ServerDataStream(('image_features','target'),False, port =5557)
iterator = valid_stream.get_epoch_iterator()
start_time = timeit.default_timer()
one_batch = next(iterator)
total_time = timeit.default_timer() - start_time

# %%
total_time
# Out:
# 0.01610269397497177

# %%
from fuel.streams import ServerDataStream
test_stream = ServerDataStream(('image_features','target'),False, port =5558)
iterator = test_stream.get_epoch_iterator()
start_time = timeit.default_timer()
one_batch = next(iterator)
total_time = timeit.default_timer() - start_time

# %%
total_time
# Out:
# 1.389254629961215

# %%
import timeit
start_time = timeit.default_timer()
for x_i, y_i in data_stream.get_epoch_iterator():
    print(x_i[0].shape)

total_time = timeit.default_timer()-start_time
# Out:
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# (3072,)
# ...

# %%
total_time
# Out:
# 49.03828126192093

# %%
valid_stream = ServerDataStream(('image_features','target'),False,port =5558)
iterator = valid_stream.get_epoch_iterator()
start_time = timeit.default_timer()
one_batch = next(iterator)
total_time = timeit.default_timer() - start_time
